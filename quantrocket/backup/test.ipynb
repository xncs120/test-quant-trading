# %%
import sys
import os
sys.path.append(os.getcwd())

from quantrocket.backup.utils import *

# %%
start_ibkr_gateway()

# %%
stop_ibkr_gateway()

# %%
view_ibkr_account_balances()

# %%
view_ibkr_account_portfolios()

# %%
save_symbol_price_data(symbol="NVDA")

# %%
view_or_update_symbol_price_data()
